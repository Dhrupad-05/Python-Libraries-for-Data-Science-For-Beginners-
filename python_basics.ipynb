# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhrupad-05/Python-Libraries-for-Data-Science-For-Beginners-/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Basic**

# %%
a= ("i am a goat")
b=",hehehe....."
print(a+ ' '+b)
# Out:
# i am a goat ,hehehe.....

# %% [markdown]
# **Slicing(List)**

# %%
countries = ['US', 'India', 'China','Brazil']
countries[0:3]
# Out:
# ['US', 'India', 'China']

# %% [markdown]
# **Funtions**

# %%
countries.append('Canada')
countries.insert(2, 'Spain')
countries2= ['uk', 'Germany']
print(countries+ countries2)
# Out:
# ['US', 'India', 'Spain', 'Spain', 'Spain', 'China', 'Brazil', 'Canada', 'Canada', 'Canada', 'uk', 'Germany']

# %% [markdown]
# **Nested List**

# %%
nested_list= [ countries, countries2]
print(nested_list)
# Out:
# [['US', 'India', 'Spain', 'Spain', 'Spain', 'China', 'Brazil', 'Canada', 'Canada', 'Canada'], ['uk', 'Germany']]

# %% [markdown]
# **Removing Elements**

# %%
countries = ['US', 'India', 'China','Brazil']
countries.remove('US')
countries
# Out:
# ['India', 'China', 'Brazil']

# %% [markdown]
# **Sort**

# %%
num=[ 5,2,8,3,9,1]
num.sort()
num
# Out:
# [1, 2, 3, 5, 8, 9]

# %% [markdown]
#  **Reverse sort**

# %%
num=[ 5,2,8,3,9,1]
num.sort(reverse=True)
num
# Out:
# [9, 8, 5, 3, 2, 1]

# %% [markdown]
# **Update**

# %%
num[1]=0
num
# Out:
# [9, 0, 5, 3, 2, 1]

# %% [markdown]
# **Copy**

# %%
countries = ['US', 'India', 'China','Brazil']
new_con =countries[:]
new_con
# Out:
# ['US', 'India', 'China', 'Brazil']

# %% [markdown]
# **Dictionary**
# format:
# my-dict={'key1': 'value1', 'key2', 'value2'}

# %%
from typing_extensions import dataclass_transform
my_data={ 'name': 'Dp', 'age':'20'}
#my_data.keys()
#my_data.values()
my_data['height']= 1.9

my_data.update({'height':2.0})
my_data
# Out:
# {'name': 'Dp', 'age': '20', 'height': 2.0}

# %% [markdown]
# **Copy fr Dictionary**

# %%
dict_1= my_data.copy()
dict_1
# Out:
# {'name': 'Dp', 'age': '20', 'height': 2.0}

# %% [markdown]
# **Removing Element**

# %%
#my_data.pop('name')
my_data.clear()

# %% [markdown]
# # **If_Else**

# %%
a = int(input("enter your age:"))
print("age is:", a)

if (a > 18):
  print("You can drive")

else:
  print("you can't drive")
# Out:
# enter your age:45
# age is: 45
# You can drive

# %% [markdown]
# **For Loop**

# %%
metadata= ['dp', 'rp','op', 'nlp']
for a in metadata:
  print(a)
# Out:
# dp
# rp
# op
# nlp

# %% [markdown]
# **Funtions**

# %%
def sum(a,b):
  x= a+b
  return x

sum(2,5)
# Out:
# 7

# %% [markdown]
# ### **Build-in-funtions**

# %%
max([13,35,9,47,49])
min([23,43564,35,643,24])
# Out:
# 23

# %%
for i in range(1,50,5):
  print(i)
# Out:
# 1
# 6
# 11
# 16
# 21
# 26
# 31
# 36
# 41
# 46

# %% [markdown]
# # **Module**

# %% [markdown]
# **Import**

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.listdir()
# Out:
# ['.config', 'sample_data']

# %% [markdown]
# **While Loop**

# %%
start = int(input("Enter the starting number: "))
end = int(input("Enter the ending number: "))

i = start
while (i <= end):
  print(i)
  i = i + 1
# Out:
# Enter the starting number: 5
# Enter the ending number: 8
# 5
# 6
# 7
# 8
